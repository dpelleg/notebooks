# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import statsmodels.api as sm

# %%
datadir = '../data/'

# %%
def _read_file(fname, enc='iso8859-8'):
    fd = open(fname, encoding=enc, errors='replace')
    df = pd.read_csv(fd, sep='|')
    return df

def add_model(df):
    df['model'] = df.apply(lambda x: '_'.join([x[y] for y in ['tozeret_cd', 'degem_cd', 'shnat_yitzur', 'sug_degem']]), axis=1)

def get_model_name(ns):
    names = pd.DataFrame(data={'model':ns})
    ret = pd.merge(names, models, how='left', on='model')[['tozeret_nm', 'kinuy_mishari']]
    return ret

# %%
def _convert_helper(df, oldcol, newcol, dictfile):
    # read dictionary
    filename=datadir + dictfile

    with open(filename, 'r') as f:
        lines = f.readlines()

    make_dict = []
    for line in lines:
        line = line.strip()
        items = line.split(',', 1)
        itm = items[0].strip()
        if len(items) > 1:
            make_dict.append((itm, items[1].strip()))
        else:
            make_dict.append((itm, itm))
    
    newdat = df[oldcol].copy()
    for (m_in, m_out) in make_dict:
        newdat[newdat.str.startswith(m_in)] = m_out
    df[newcol] = newdat
    
def convert_make(df, oldcol='tozeret_nm', newcol='make'):
    _convert_helper(df, oldcol, newcol, 'makes_dict.csv')

def convert_color(df, oldcol='tzeva_rechev', newcol='color'):
    _convert_helper(df, oldcol, newcol, 'color_dict.csv')

# %%
# source : https://data.gov.il/dataset/private-and-commercial-vehicles

#df = pd.read_csv('data/rechev-small.csv', encoding='iso-8859-1', sep='|')

def read_file(fname):
    fname = datadir + fname
    df = _read_file(fname)

    for c in ['mispar_rechev', 'degem_cd', 'tozeret_cd', 'shnat_yitzur']:
        df[c] = df[c].astype(str)

    df['test']= pd.to_datetime(df.mivchan_acharon_dt)
    df['test_expiry']= pd.to_datetime(df.tokef_dt)
    df['year'] = df['shnat_yitzur'].astype(int)
    c='moed_aliya_lakvish'
    df[c] = pd.to_datetime(df[c], format="%Y-%m")
    df['kvish_ym'] = df[c].dt.strftime('%Y%m')
    df['sidra'] = df['mispar_rechev'].apply(lambda k : k[-2:])
    add_model(df)
    convert_make(df)
    return df

# %%
# merge with the master file with all vehicles
df = read_file('rechev.csv')

convert_color(df)

df['metal'] = df['tzeva_rechev'].str.contains('מטאלי') | df['tzeva_rechev'].str.contains('מטלי')

# %%
palette = {
    'white': (255, 255, 255),
    'silver': (192, 192, 192),
    'grey': (128, 128, 128),
    'black': (0, 0, 0),
    'blue': (0, 0, 255),
    'beige': (245, 245, 220),
    'red': (255, 0, 0),
    'light blue': (173, 216, 230),
    'green': (0, 128, 0),
    'brown': (165, 42, 42),
    'bronze': (205, 127, 50),
    'gold': (255, 215, 0),
    'orange': (255, 165, 0),
    'eggshell': (252, 230, 201),
    'yellow': (255, 255, 0)
}

rgb_palette = {k: f"rgb{v}" for k, v in palette.items()}

color_names = {
    'לבן': 'white',
    'כסף': 'silver',
    'אפור': 'grey',
    'שחור': 'black',
    'כחול': 'blue',
    'בז': 'beige',
    'אדום': 'red',
    'תכלת': 'light blue',
    'ירוק': 'green',
    'חום': 'brown',
    'ברונזה': 'bronze',
    'זהב': 'gold',
    'כתום': 'orange',
    'קרם': 'eggshell',
    'צהוב': 'yellow'
}


heb_palette = {k: rgb_palette.get(v, None) for k, v in color_names.items()}

# %%
cl='חציל'
df[df['color'].str.contains(cl)]['kinuy_mishari'].value_counts().head(20)
# Out:
# MAZDA 2         1068
# MAZDA 6          643
# MAZDA 3          395
# U5               319
# MAZDA3           162
# FOCUS            136
# FIESTA           126
# MAZDA3-SPORT      65
# CADDY MAXI        64
# MAZDA 5           51
# MAZDA3 SPORT      28
# GALAXY            24
# MONDEO            23
# CTS               21
# S-MAX             19
# MONDE0            19
# IMPREZA           18
# FORESTER          18
# SONATA            11
# XT5                9
# Name: kinuy_mishari, dtype: int64

# %%
def show_colors(df, topN, title, exclude=[]):
    # Calculate color distribution by year
    color_counts = df.query('color not in @exclude').groupby(['year', 'color']).size().reset_index(name='count')
    color_counts['percent'] = color_counts.groupby('year')['count'].apply(lambda x: x / x.sum())

    # Only show the N largest colors by counts
    top_colors = color_counts.groupby('color')['count'].sum().nlargest(topN).index
    color_counts = color_counts[color_counts['color'].isin(top_colors)]

    # Map color names to color codes using the colormap
    color_counts['color_code'] = color_counts['color'].map(color_names)

    # Create stacked bar chart
    fig = px.bar(color_counts, x='year', y='percent', color='color', title=title,
             color_discrete_map=heb_palette, # Set discrete colors
             hover_data=['color', 'count'], # Show additional info on hover
             labels={'year': 'שנה', 'percent': 'שיעור', 'color': 'צבע'})
    fig.update_layout(barmode='stack') # Set stacked mode
    fig.update_yaxes(tickformat=".0%")
    fig.show()
    return color_counts

# %%
c=show_colors(df, 15, title="Color distribution by year")
# Out:
# <div>                            <div id="15bc7865-e508-4e55-ba62-eb14ef1b70da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15bc7865-e508-4e55-ba62-eb14ef1b70da")) {                    Plotly.newPlot(                        "15bc7865-e508-4e55-ba62-eb14ef1b70da",                        [{"alignmentgroup":"True","customdata":[["אדום",58],["אדום",104],["אדום",135],["אדום",125],["אדום",170],["אדום",307],["אדום",273],["אדום",387],["אדום",426],["אדום",663],["אדום",870],["אדום",1092],["אדום",3449],["אדום",2295],["אדום",3411],["אדום",4663],["אדום",5277],["אדום",5168],["אדום",6539],["אדום",5949],["אדום",6066],["אדום",6658],["אדום",5356],["אדום",3900],["אדום",3210],["אדום",4018],["אדום",3698],["אדום",1276]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"אדום","marker":{"color":"rgb(255, 0, 0)","pattern":{"shape":""}},"name":"אדום","offsetgroup":"אדום","orientation":"v","showlegend":true,"textposition":"auto","x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.0675990675990676,0.046804680468046804,0.02999333481448567,0.018040121229614663,0.017457383446292874,0.017092589499471077,0.014333718366061116,0.01601357222658998,0.012530885986586656,0.013667003360062666,0.012470793973883005,0.012754476330635272,0.017798901824787383,0.01880515564441458,0.02080943898094146,0.02628019432577747,0.031127050509936235,0.028221160409556315,0.030354515112268533,0.025297884826372057,0.022538707052542014,0.024732265242214984,0.020704958211240056,0.015526652095500854,0.014911021614013573,0.013621400990585706,0.013420821508154837,0.010404350910380705],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[
],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"בורדו","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"בורדו","offsetgroup":"בורדו","orientation":"v","showlegend":true,"textposition":"auto","x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.07371794871794872,0.0535475234270415,0.03902185223725286,0.0210016155088853,0.01815950920245399,0.022653242522949365,0.028152415870106064,0.021815537510604777,0.007220216606498195,0.004653868528214078,0.006634657354866871,0.002685580498553918,0.008370123582412894,0.012674869374683971,0.00681539854107875,0.008918743473229658,0.016577690362461366,0.016788277866761583,0.012894833583123605,0.015261858020391362,0.004065389790718315,0.0030163127116035705,0.0037573168802404683,0.00625970253893535,0.006958556561364616,0.005530830056604589,0.008403727248976749,0.0019430792090524632],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["בז",33],["בז",113],["בז",126],["בז",361],["בז",617],["בז",1121],["בז",1095],["בז",1444],["בז",1860],["בז",2863],["בז",4365],["בז",6167],["בז",14768],["בז",6647],["בז",7409],["בז",5671],["בז",2885],["בז",2602],["בז",4025],["בז",4104],["בז",4598],["בז",3056],["בז",2111],["בז",1523],["בז",823],["בז",719],["בז",1009],["בז",455]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"בז","marker":{"color":"rgb(245, 245, 220)","pattern":{"shape":""} ...

# %%
color_counts = df.groupby(['year', 'color']).size().reset_index(name='count')
color_counts['percent'] = color_counts.groupby('year')['count'].apply(lambda x: x / x.sum())
color_counts.query("year > 2013").groupby("color").sum().sort_values(by='count')
# Out:
#                     year    count   percent
# color
# מלאנג מטאלי         2020        1  0.000005
# מנדרינה מט          4030        2  0.000008
#  לא ידוע            8062       17  0.000071
# חרדל                4029       20  0.000089
# אדמדם מטאלי        14124       23  0.000091
# טורקיז בהיר מטאלי  12112       27  0.000102
# אחר                12109       30  0.000114
# נחושת              20185      328  0.001468
# רוז מתכתי          12112      358  0.001369
# סהרה               20185      387  0.001528
# חציל               20185      417  0.001850
# טורקיז כהה         20185      600  0.002438
# ורוד               20185      830  0.003684
# פלטינה             18166      875  0.003926
# רב גווני           20185     1646  0.006662
# בורדו              20185     1849  0.007721
# זהב                20185     2053  0.008550
# סגול               20185     2322  0.009549
# בורדו מטל          20185     2662  0.012364
# טורקיז מטאלי       20185     2929  0.012724
# צהוב               20185     4275  0.017630
# טורקיז             20185     4439  0.017367
# שן פיל             20185     7164  0.029231
# קרם                20185     7985  0.032518
# כתום               20185     8668  0.035082
# ירוק               20185     8783  0.037660
# ברונזה             20185     9721  0.040006
# חום                20185    17757  0.072029
# תכלת               20185    21246  0.087997
# בז                 20185    22423  0.092429
# אדום               20185    46670  0.191513
# כחול               20185    74207  0.306973
# שחור               20185   308948  1.288113
# אפור               20185   369370  1.545503
# כסף                20185   386964  1.598558
# לבן                20185  1091223  4.533077

# %%
private = "פרטי"
c=show_colors(df.query('baalut != @private'), 15, 'צבעי רכב בבעלות לא פרטית')
#c = show_colors(df.query('make == "BMW"'), 15)
# Out:
# <div>                            <div id="d6caf276-18a1-4807-8184-fcf8db8fe238" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d
class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c45d668-4519-40eb-ba29-f67c02a48782")) {                    Plotly.newPlot(                        "4c45d668-4519-40eb-ba29-f67c02a48782",                        [{"alignmentgroup":"True","customdata":[["אפור",7],["אפור",4],["אפור",162],["אפור",181],["אפור",1342],["אפור",4572],["אפור",4784]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"אפור","marker":{"color":"rgb(128, 128, 128)","pattern":{"shape":""}},"name":"אפור","offsetgroup":"אפור","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.0603448275862069,0.027777777777777776,0.26688632619439867,0.11783854166666667,0.12026167219284882,0.16326239108698756,0.24694161978010634],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["כחול",12],["כחול",11],["כחול",22],["כחול",64],["כחול",575],["כחול",2381],["כחול",1167]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"כחול","marker":{"color":"rgb(0, 0, 255)","pattern":{"shape":""}},"name":"כחול","offsetgroup":"כחול","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.10344827586206896,0.0763888888888889,0.036243822075782535,0.041666666666666664,0.05152791468769603,0.08502356806170547,0.06023847622980437],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["כסף",8],["כסף",2],["כסף",32],["כסף",42],["כסף",229],["כסף",1955],["כסף",1316]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"כסף","marker":{"color":"rgb(192, 192, 192)","pattern":{"shape":""}},"name":"כסף","offsetgroup":"כסף","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.06896551724137931,0.013888888888888888,0.05271828665568369,0.02734375,0.020521552110404156,0.06981145550635623,0.067929592732153],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["לבן",84],["לבן",124],["לבן",280],["לבן",677],["לבן",5993],["לבן",14501],["לבן",9485]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"לבן","marker":{"color":"rgb(255, 255, 255)","pattern":{"shape":""}},"name":"לבן","offsetgroup":"לבן","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.7241379310344828,0.8611111111111112,0.4612850082372323,0.4407552083333333,0.537055291692804,0.5178188830167119,0.48959892634078356],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["שחור",5],["שחור",2],["שחור",94],["שחור",217],["שחור",1546],["שחור",2797],["שחור",1689]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"שחור","marker":{"color":"rgb(0, 0, 0)","pattern":{"shape":""}},"name":"שחור","offsetgroup":"שחור","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.04310344827586207,0.013888888888888888,0.15485996705107083,0.14127604166666666,0.13854288018639663,0.09987858877303242,0.08718319310380426],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["אדום",3],["אדום",57],["אדום",529],["אדום",566],["אדום",241]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"אדום","marker":{"color":"rgb(255, 0, 0)","pattern":{"shape":""}},"name":"אדום","offsetgroup":"אדום"," ...

# %%
import numpy as np
from scipy.stats import entropy

def categorical_entropy(x):
    counts = np.unique(x, return_counts=True)[1]
    return entropy(counts)

# %%
entropy_df = df.groupby('make')['color'].apply(categorical_entropy).reset_index(name='entropy')

# %%
# select the big makes
makes = df.groupby('make').size()
big_makes = makes[makes > 10000].index.tolist()

# %%
entropy_df.query("entropy > 0 and make in @big_makes").sort_values(by='entropy', ascending=False)
# Out:
#              make   entropy
# 34        דייהטסו  2.065775
# 62         סוזוקי  2.039212
# 88         שברולט  2.012149
# 37          הונדה  1.962596
# 18           אופל  1.904063
# 54           מזדה  1.881787
# 61         סובארו  1.864871
# 63           סיאט  1.862905
# 67          סקודה  1.852915
# 44         יונדאי  1.828991
# 58          ניסאן  1.777569
# 84        קרייזלר  1.770471
# 87            רנו  1.739857
# 71      פולקסווגן  1.739523
# 73           פורד  1.723534
# 55       מיצובישי  1.704674
# 40         טויוטה  1.699640
# 76           פיאט  1.686894
# 31          דאציה  1.672689
# 83            קיה  1.669492
# 14             MG  1.653117
# 1             BMW  1.652062
# 77          פיג'ו  1.636087
# 39          וולבו  1.623318
# 23  איסוזו תאילנד  1.415851
# 57          מרצדס  1.355229
# 64        סיטרואן  1.348116
# 17          אאודי  1.339665
# 51          לקסוס  1.252537
# 42           טסלה  1.092244
# 2             BYD  0.974561
# 10          Geely  0.974411

# %%
make = 'Geely'
c = show_colors(df.query('make == @make'), 15, make)
# Out:
# <div>                            <div id="5652e87e-a3ef-4f17-802a-7d0083770ab1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5652e87e-a3ef-4f17-802a-7d0083770ab1")) {                    Plotly.newPlot(                        "5652e87e-a3ef-4f17-802a-7d0083770ab1",                        [{"alignmentgroup":"True","customdata":[["אדום",4],["אדום",117],["אדום",1]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"אדום","marker":{"color":"rgb(255, 0, 0)","pattern":{"shape":""}},"name":"אדום","offsetgroup":"אדום","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2022,2023],"xaxis":"x","y":[0.025,0.01720082328726845,0.0002925687536571094],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["כחול",42],["כחול",1498],["כחול",614]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"כחול","marker":{"color":"rgb(0, 0, 255)","pattern":{"shape":""}},"name":"כחול","offsetgroup":"כחול","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2022,2023],"xaxis":"x","y":[0.2625,0.2202293443104969,0.17963721474546518],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["כסף",23],["כסף",1069],["כסף",613]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"כסף","marker":{"color":"rgb(192, 192, 192)","pattern":{"shape":""}},"name":"כסף","offsetgroup":"כסף","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2022,2023],"xaxis":"x","y":[0.14375,0.15715965892384592,0.17934464599180808],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["לבן",91],["לבן",4117],["לבן",2190]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"לבן","marker":{"color":"rgb(255, 255, 255)","pattern":{"shape":""}},"name":"לבן","offsetgroup":"לבן","orientation":"v","showlegend":true,"textposition":"auto","x":[2021,2022,2023],"xaxis":"x","y":[0.56875,0.6052631578947368,0.6407255705090696],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["אפור",1]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"אפור","marker":{"color":"rgb(128, 128, 128)","pattern":{"shape":""}},"name":"אפור","offsetgroup":"אפור","orientation":"v","showlegend":true,"textposition":"auto","x":[2022],"xaxis":"x","y":[0.00014701558365186709],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...

# %%
make = 'מרצדס'
c = show_colors(df.query('make == @make'), 15, make)
# Out:
# <div>                            <div id="678e481b-5087-4e04-b1da-ba4794f4d14c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("678e481b-5087-4e04-b1da-ba4794f4d14c")) {                    Plotly.newPlot(                        "678e481b-5087-4e04-b1da-ba4794f4d14c",                        [{"alignmentgroup":"True","customdata":[["אפור",3],["אפור",17],["אפור",7],["אפור",11],["אפור",18],["אפור",9],["אפור",1],["אפור",102],["אפור",93],["אפור",100],["אפור",120],["אפור",183],["אפור",216],["אפור",283],["אפור",327],["אפור",213],["אפור",166],["אפור",179],["אפור",322],["אפור",588],["אפור",699],["אפור",352]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"אפור","marker":{"color":"rgb(128, 128, 128)","pattern":{"shape":""}},"name":"אפור","offsetgroup":"אפור","orientation":"v","showlegend":true,"textposition":"auto","x":[1996,1997,1998,1999,2000,2001,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0
2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.008333333333333333,0.008368200836820083,0.023809523809523808,0.010958904109589041,0.004524886877828055,0.00655307994757536,0.006009615384615385,0.02616516762060507,0.019143576826196475,0.02185596560372626,0.029744669649907872,0.03192019950124688,0.042178929449593346,0.03778096604495457,0.04505800019173617,0.05971206042010857,0.032176719790195686,0.029677021506205194,0.021996906684997423,0.02696420269642027,0.04439601494396015,0.03445623750192278,0.036768342951360264,0.03293084522502744,0.033036483769031885,0.038955034100104036,0.04734895191122072],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["אפור",21],["אפור",14],["אפור",2],["אפור",4],["אפור",2],["אפור",3],["אפור",2],["אפור",1],["אפור",40],["אפור",191],["אפור",434],["אפור",1078],["אפור",740],["אפור",1499],["אפור",1533],["אפור",1315],["אפור",1652],["אפור",2548],["אפור",2367],["אפור",2907],["אפור",3311],["אפור",2642],["אפור",2432],["אפור",1629],["אפור",2097],["אפור",2080],["אפור",842]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"אפור","marker":{"color":"rgb(128, 128, 128)","pattern":{"shape":""}},"name":"אפור","offsetgroup":"אפור","orientation":"v","showlegend":true,"textposition":"auto","x":[1996,1997,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.175,0.058577405857740586,0.005479452054794521,0.00904977375565611,0.002621231979030144,0.0029069767441860465,0.002403846153846154,0.0008176614881439084,0.020151133501259445,0.06843425295592978,0.1142405896288497,0.10753117206982543,0.13996595422735011,0.14337637494021999,0.1469657750934714,0.15518055227755487,0.16663304417994754,0.196407924150158,0.20338546141948788,0.22524407252440726,0.20616438356164385,0.2031995077680357,0.20049464138499587,0.17881448957189902,0.20080436656133294,0.24043463183447,0.20764488286066585],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["טורקיז",2],["טורקיז",16],["טורקיז",1],["טורקיז",1],["טורקיז",70],["טורקיז",490],["טורקיז",249],["טורקיז",90],["טורקיז",124],["טורקיז",66],["טורקיז",18],["טורקיז",44],["טורקיז",8]],"hovertemplate":"צבע=%{customdata[0]}<br>שנה=%{x}<br>שיעור=%{y}<br>count=%{customdata[1]}<extra></extra>","legendgroup":"טורקיז","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"טורקיז","offsetgroup":"טורקיז","orientation":"v","showlegend":true,"textposition":"auto","x":[1996,1997,1999,2012,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.016666666666666666,0.06694560669456066,0.0027397260273972603,0.0001180080245456691,0.00601477917167898 ...

# %%
df.query('make == @make')['year'].value_counts()
# Out:
# 2017    16060
# 2018    13002
# 2014    12973
# 2016    12906
# 2019    12130
# 2015    11638
# 2010    10455
# 2021    10443
# 2011    10431
# 2008    10025
# 2013     9914
# 2020     9110
# 2022     8651
# 2012     8474
# 2009     5287
# 2023     4055
# 2007     3799
# 2006     2791
# 2005     1985
# 2004     1223
# 2002     1032
# 2003      832
# 2001      763
# 2000      442
# 1998      378
# 1999      365
# 1997      239
# 1996      120
# Name: year, dtype: int64

# %%
df.year.value_counts()
# Out:
# 2021    294977
# 2022    275542
# 2017    269203
# 2016    269137
# 2018    258682
# 2019    251181
# 2015    235158
# 2014    215421
# 2020    215277
# 2008    193776
# 2013    183125
# 2011    177434
# 2012    169531
# 2010    163916
# 2023    122641
# 2009    122041
# 2007     85617
# 2006     69763
# 2005     48511
# 2004     33996
# 2003     24167
# 2002     19046
# 2001     17961
# 2000      9738
# 1999      6929
# 1998      4501
# 1997      2222
# 1996       858
# Name: year, dtype: int64

# %%
# metallic paints
metal = df.groupby('year').metal.mean().reset_index()

# %%
# create plot
fig = px.line(metal, x='year', y='metal', width=800, height=500)

# set line width and smoothing
fig.update_traces(line=dict(width=3, shape='spline', smoothing=1.3))

# set axis labels and title
fig.update_layout(xaxis_title='שנה', yaxis_title='שיעור צבע מטלי', title='צבע מטלי לפי זמן')
fig.update_yaxes(tickformat=".0%")

# show plot
fig.show()
# Out:
# <div>                            <div id="bbcd5ba1-f867-4bee-9d04-f0e69128a9b3" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbcd5ba1-f867-4bee-9d04-f0e69128a9b3")) {                    Plotly.newPlot(                        "bbcd5ba1-f867-4bee-9d04-f0e69128a9b3",                        [{"hovertemplate":"year=%{x}<br>metal=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid","shape":"spline","smoothing":1.3,"width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0.002331002331002331,0.0027002700270027003,0.0033325927571650742,0.008947900129888872,0.033887861983980284,0.0487166638828573,0.062165284049144176,0.2261348119336285,0.2019355218260972,0.1911731359897755,0.21885526711867323,0.24529007089713492,0.19767153827099332,0.2204423103711048,0.24134922765318823,0.25236989528500736,0.2639517256430977,0.23030170648464163,0.21514615566727477,0.18410175286403185,0.17906122160832588,0.1829845878389171,0.1711599570128575,0.17315800160043954,0.18109691235013495,0.1898283594992152,0.16350320459312917,0.16541776404301986],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"m ...

# %%
df.groupby('make')['metal'].mean().sort_values()
# Out:
# make
# Aiways       0.000000
# למבורגיני    0.000000
# מאן פולין    0.000000
# טלקו הודו    0.000000
# ואז          0.000000
#                ...
# דייהטסו      0.411965
# טויוטה       0.429303
# רנו          0.430889
# EVEASY       0.444444
# קארמה        0.500000
# Name: metal, Length: 89, dtype: float64

# %%
df[df.make == 'רנו']['tzeva_rechev'].value_counts()
# Out:
# שנהב לבן             48622
# כסף מטלי             18312
# אפור כהה מטלי        11409
# שחור מטלי            10379
# בז מטאלי              4374
# קרם                   3446
# אדום מטל              3045
# כחול מטל              1516
# אפור מטל              1171
# כתום                  1155
# כחול פחם מטלי          751
# קפה מטאלי              348
# ירוק מטל               307
# רב גווני               284
# חום                    249
# כחול כהה               237
# כחול                   227
# צהוב                   175
# אפור כחול מטלי         172
# תכלת מטאלי             145
# טורקיז מטאלי           115
# אפור                   107
# אפור כהה                77
# תכלת                    71
# טורקיז                  61
# שחור                    60
# כסף                     57
# ירוק זהב מטלי           56
# צהוב מטאלי              43
# זהב מטאלי               43
# כסף כחלחל מטלי          28
# אדום                    22
# בורדו מטל               19
# זהוב                    18
# אדום כהה (יין)          18
# בורדו                   16
# סגול כהה                14
# ירוק                     8
# אפור בהיר מטלי           8
# כחול בהיר                7
# ירוק זית מטלי            6
# סגול בהיר                4
#  לא ידוע                 3
# זהב                      2
# ירוק כסוף                2
# בז                       2
# ירוק בהיר                2
# ורוד                     2
# חום בהיר                 1
# כסף תכלת מטלי            1
# כסוף כהה מטלי            1
# חציל                     1
# צהוב לימון               1
# ירקרק מטלי               1
# סגול                     1
# שן פיל                   1
# טורקיז בהיר מטאלי        1
# Name: tzeva_rechev, dtype: int64
