# %%
import pandas as pd
import requests
import json
from pyproj import Transformer
from math import radians, cos, sin, asin, sqrt
import os.path
import time

datapath='../data/'
secret_file = '../secrets/gcloud.json'

origin="Haifa Hof Hacarmel"
origin="כחל"
origin_english = 'Kahal'
MODE='driving'
#MODE='transit'
MAX_ELEM = 25

filename = f'{datapath}dist_{MODE}_{origin}.csv'
assert not os.path.isfile(filename), "Data already exists, will not re-fetch it to reduce costs"

with open(secret_file) as json_file:
    secrets = json.load(json_file)
    api_key=secrets['api_key']

# %%
transformer = Transformer.from_crs('epsg:2039', 'epsg:4326')

def get_distances(origin, destinations, api_key):
    if isinstance(origin, list):
        origin = ('|').join(origin)
        
    params = {
        'origins' : origin,
        'destinations' : ('|').join(destinations),
        'units' : 'metric',
        'mode' : MODE,
        'key' :  api_key
    }

    response = requests.get(
                    url = 'https://maps.googleapis.com/maps/api/distancematrix/json?',
                    params = params,
                    )
    return response

def coords_to_lonlat(c):
    s = f'{c:.0f}'

    if s == 'nan':
        return None, None, None
    assert len(s) == 10, "Input string must be 10 characters long"
    X = int(s[:5] + '0')
    Y = int(s[5:] + '0')

    lat, lon = transformer.transform(X, Y)
    return lon, lat, f'{lat:.4f},{lon:.4f}'

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# %%
# source: https://www.cbs.gov.il/he/publications/Pages/2019/יישובים-בישראל.aspx
places = pd.read_excel(datapath + 'places-cbs.xlsx')

places.rename(columns={'שם יישוב באנגלית' : 'name', 'סך הכל אוכלוסייה 2021' : 'pop', 'קואורדינטות' : 'coords'}, inplace=True)

places[['lon', 'lat', 'lonlat']] = places['coords'].apply(lambda x: pd.Series(coords_to_lonlat(x)))
origin_query = places.query('name == @origin_english')
if len(origin_query) == 0:
    raise ValueError(f'No place name in the file found for {origin_english}')
origin_coords = origin_query.iloc[0]['coords']

dests = places.query('pop > 100 and pop < 1000').copy().reset_index().drop(columns='index')
print(f'{len(dests)} destinations')
orig_lon, orig_lat, orig_lonlat = coords_to_lonlat(origin_coords)
# Out:
# 698 destinations

# %%
dests['distance'] = None
dests['duration'] = None
dests['g_orig'] = None
dests['g_dest'] = None
dests['crow_dist'] = None
dests['mode'] = MODE

s_idx = 0
dlist = dests['lonlat'].to_list()
while s_idx < len(dlist):
    print(s_idx, end='...')
    e_idx = min(s_idx+MAX_ELEM, len(dests))
    r = range(s_idx, e_idx)
    dests_call = dlist[s_idx:e_idx]
    response = get_distances(origin, dests_call, api_key)
    time.sleep(0.5)
    matrix = response.json()
    DESTINATIONS=matrix['destination_addresses']
    ORIGIN=matrix['origin_addresses'][0]
    matrix = matrix['rows'][0]['elements']

    o_origin, o_dest, o_distance, o_duration, o_crow = [], [], [], [], []

    num_failed = 0
    for i, element in enumerate(matrix):
        o_origin.append(ORIGIN)
        o_dest.append(DESTINATIONS[i])
        o_crow.append(1000.*haversine(orig_lon, orig_lat, dests.loc[s_idx+i, 'lon'], dests.loc[s_idx+i, 'lat']))
        if element['status'] == 'OK':
            o_distance.append(element['distance']['value'])
            o_duration.append(element['duration']['value'])
        else:
            num_failed += 1
            o_distance.append(None)
            o_duration.append(None)
    if num_failed/len(dests_call) > 0.1:
        raise ValueError(f'Too many failed calls: {num_failed}/{len(dests_call)}, check the origin place name')
    
    dests.loc[r, 'distance'] = o_distance
    dests.loc[r, 'duration'] = o_duration
    dests.loc[r, 'g_orig'] = o_origin
    dests.loc[r, 'g_dest'] = o_dest
    dests.loc[r, 'crow_dist'] = o_crow
    
    s_idx += MAX_ELEM
# Out:
# 0...25...50...75...100...125...150...175...200...225...250...275...300...325...350...375...400...425...450...475...500...525...550...575...600...625...650...675...

# %%
def batch_get_distances(places, origin_idx, destination_idxs, api_key, mode='driving', max_elem=25):
    results = []#= pd.DataFrame(columns=['distance', 'duration', 'g_orig', 'g_dest', 'crow_dist', 'mode', 'origin_idx', 'dest_idx'])
    
    origin = places.loc[origin_idx, 'lonlat']
    origin_lat, origin_lon, origin_name = places.loc[origin_idx, ['lat', 'lon', 'name']]

    s_idx = 0
    while s_idx < len(destination_idxs):
        print(s_idx, end='...')
        e_idx = min(s_idx + max_elem, len(destination_idxs))
        
        batch_dest_idxs = destination_idxs[s_idx:e_idx]
        destinations = places.loc[batch_dest_idxs, 'lonlat'].tolist()
        
        response = get_distances(origin, destinations, api_key)
        time.sleep(0.25)
        matrix = response.json()
        
        DESTINATIONS = matrix['destination_addresses']
        ORIGIN = matrix['origin_addresses'][0]
        elements = matrix['rows'][0]['elements']

        for j, element in enumerate(elements):
            dest_idx = batch_dest_idxs[j]
            dest_lat, dest_lon, dest_name = places.loc[dest_idx, ['lat', 'lon', 'name']]
            
            result_row = {
                'g_orig': ORIGIN,
                'g_dest': DESTINATIONS[j],
                'crow_dist': 1000 * haversine(origin_lon, origin_lat, dest_lon, dest_lat),
                'mode': mode,
                'origin_idx': origin_idx,
                'dest_idx': dest_idx,
                'orig_name': origin_name,
                'dest_name': dest_name,
            }
            
            if element['status'] == 'OK':
                result_row['distance'] = element['distance']['value']
                result_row['duration'] = element['duration']['value']
            else:
                result_row['distance'] = None
                result_row['duration'] = None
            
            results.append(result_row)
    
        s_idx += max_elem
    
    ret = pd.DataFrame(results)
    ret['speed'] = ret['crow_dist']/ret['duration']*3.6
    ret['ratio'] = ret['crow_dist']/ret['distance']

    return ret

origin_query = places.query('name == @origin_english')
if len(origin_query) == 0:
    raise ValueError(f'No place name in the file found for {origin_name}')
origin_idx = origin_query.index[0]
destination_idxs = places.query('pop > 900 and pop < 1000').index.to_list()
results = batch_get_distances(places, origin_idx, destination_idxs, api_key, MODE, MAX_ELEM)
# Out:
# 0...25...50...75...

# %%
results
# Out:
#                g_orig                                 g_dest      crow_dist  \
# 0   65, Kahal, Israel                    108, Aderet, Israel  145135.585066
# 1   65, Kahal, Israel                     93, Ahihud, Israel   31567.582518
# 2   65, Kahal, Israel        Elyakim Center, Eliakim, Israel   50450.378037
# 3   65, Kahal, Israel            Arbel St 49, Eshhar, Israel   19606.937147
# 4   65, Kahal, Israel  Ha-Rishonim St 30, Beit Herut, Israel   82795.502280
# ..                ...                                    ...            ...
# 73  65, Kahal, Israel                 ההר 72, Shamir, Israel   33698.695512
# 74  65, Kahal, Israel         Haikarim St 71, Shafir, Israel  151721.063730
# 75  65, Kahal, Israel              14, Talmei Elazar, Israel   70255.560293
# 76  65, Kahal, Israel                     18, Tlamim, Israel  167252.769996
# 77  65, Kahal, Israel  Ma'ale Shimshon St 161, Tarum, Israel  132816.397040
#
#        mode  origin_idx  dest_idx orig_name      dest_name  distance  \
# 0   driving         664        32     Kahal        Adderet    203772
# 1   driving         664       143     Kahal         Ahihud     40279
# 2   driving         664       179     Kahal        Elyaqim     69129
# 3   driving         664       213     Kahal         Eshhar     35230
# 4   driving         664       262     Kahal      Bet Herut    110903
# ..      ...         ...       ...       ...            ...       ...
# 73  driving         664      1411     Kahal         Shamir     41938
# 74  driving         664      1426     Kahal         Shafir    187649
# 75  driving         664      1457     Kahal  Talme El'azar     95868
# 76  driving         664      1462     Kahal        Telamim    218524
# 77  driving         664      1482     Kahal          Tarum    176854
#
#     duration      speed     ratio
# 0       7785  67.114721  0.712245
# 1       2255  50.396141  0.783723
# 2       2819  64.427585  0.729800
# 3       2405  29.349261  0.556541
# 4       4446  67.040893  0.746558
# ..       ...        ...       ...
# 73      2373  51.123179  0.803536
# 74      7123  76.680588  0.808536
# 75      3873  65.303387  0.732836
# 76      8098  74.352923  0.765375
# 77      6780  70.521981  0.750995
#
# [78 rows x 12 columns]

# %%
results.sort_values(by='ratio')[['distance', 'duration', 'speed', 'crow_dist', 'orig_name', 'dest_name']]
# Out:
#     distance  duration      speed      crow_dist orig_name         dest_name
# 51     46628      2419  34.267857   23026.095962     Kahal             Natur
# 7      40484      1874  40.146212   20898.333877     Kahal        Bet Rimmon
# 69    170798      6844  47.774616   90824.853309     Kahal           Rehelim
# 33     42775      2583  32.149560   23067.309004     Kahal           Yodefat
# 52     97307      4055  47.105722   53059.362010     Kahal         Nir Ezyon
# ..       ...       ...        ...            ...       ...               ...
# 74    187649      7123  76.680588  151721.063730     Kahal            Shafir
# 49    194063      7415  76.366931  157294.665741     Kahal             Negba
# 14    202714      8002  73.924549  164317.844415     Kahal              Ge'a
# 44    239638      8895  78.750222  194578.674492     Kahal            Maslul
# 42     37108      2016  54.756982   30663.909823     Kahal  Lahavot HaBashan
#
# [78 rows x 6 columns]

# %%
dests.query('crow_dist < 15000').sort_values(by='speed')[['distance', 'duration', 'speed', 'crow_dist', 'name']][0:20]
# Out:
#     distance duration      speed     crow_dist                  name
# 306    86299     3846   5.835378   6234.128851          Kefar Gallim
# 197    87939     3980   6.763965   7477.939096             HaHoterim
# 73     84680     3896   7.465841   8079.699177              Bet Oren
# 301    65823     3098   8.748249    7528.35426          Kefar Bialik
# 94     97097     4117   8.755019  10012.336714              Bet Zevi
# 523    96579     4154  10.209472  11780.595772                En Hod
# 530   100218     4372  10.278262   12482.37784               Ein Hod
# 485    97505     4083  10.305967  11688.684028             Nir Ezyon
# 322    65899     2836  12.028844   9476.056328     Kefar Hasidim Bet
# 321    65792     2889  12.234254    9817.98867    Kefar Hasidim Alef
# 311    67289     2970  12.281812  10132.494824      Kefar HaMakkabbi
# 25     66801     2882  12.407749   9933.092292                  Usha
# 312    66857     3025  12.780154  10738.879001  Kefar HaNo'ar Hadati
# 535    92997     3881  13.895827  14980.473512             En Karmel
# 56     62411     2752  15.439283  11802.474054                  Afeq
# 215    67218     2877  15.662577  12517.009702              Khawaled
# 330    50399     2910  15.955348  12897.239769         Kefar Masaryk
# 597    68518     2965  17.095734  14080.236313               Ras Ali
# 667    60127     2611  18.199421  13199.635624       Sha'ar HaAmaqim

# %%
dests.to_csv(filename, index=False)

# %%
def nearby_places(places, max_dist):
    # find all pairs of places which are less than max_dist apart in aerial distance
    pairs = []
    for i, p1 in places.iterrows():
        for j, p2 in places.iterrows():
            if i < j and haversine(p1['lon'], p1['lat'], p2['lon'], p2['lat']) < max_dist:
                pairs.append((p1['name'], p2['name']))
    return pairs

# %%
nearby_pairs = nearby_places(places.query("pop < 1000"), 3)

# %%
nearby_pairs
# Out:
# [('Avtalyon', 'Hararit'),
#  ("Avi'el", 'Allone Yizhaq'),
#  ('Avivim', "Yir'on"),
#  ('Avigedor', 'En Zurim'),
#  ('Avigedor', 'Shafir'),
#  ('Avigedor', 'Timmorim'),
#  ('Avital', "Yizre'el"),
#  ('Avital', 'Metav'),
#  ('Avital', 'Perazon'),
#  ("Avi'ezer", "Newe Mikha'el"),
#  ('Even Menahem', 'Kefar Rozenwald(Zarit)'),
#  ('Even Menahem', "Netu'a"),
#  ('Even Menahem', 'Shomera'),
#  ('Even Menahem', 'Shetula'),
#  ('Even Sappir', "En Karem-B.S.Haqla'i"),
#  ('Even Sappir', 'Zova'),
#  ('Avshalom', 'Deqel'),
#  ('Avshalom', 'Yevul'),
#  ('Avshalom', 'Yated'),
#  ('Avshalom', 'Sede Avraham'),
#  ('Adora', 'Telem'),
#  ('Addirim', 'Baraq'),
#  ('Addirim', 'Gadish'),
#  ('Addirim', 'Devora'),
#  ('Addirim', 'Hever'),
#  ('Addirim', 'Metav'),
#  ('Addirim', 'Ram-On'),
#  ('Adamit', "Ya'ara"),
#  ('Adderet', "Newe Mikha'el"),
#  ('Odem', 'El-Rom'),
#  ('Ohad', 'Yesha'),
#  ('Ohad', 'Mivtahim'),
#  ('Ohad', "Ammi'oz"),
#  ('Ohad', 'Zohar'),
#  ('Ohad', 'Sede Nizzan'),
#  ('Ohad', 'Talme Eliyyahu'),
#  ('Omen', 'Gadish'),
#  ('Omen', 'Devora'),
#  ('Omen', 'Hever'),
#  ('Omen', "Mele'a"),
#  ('Omen', 'Nir Yafe'),
#  ('Omez', "HaMa'pil"),
#  ('Or HaGanuz', 'Kaddita'),
#  ('Or HaGanuz', 'Kefar Hoshen'),
#  ('Or HaNer', 'Ibbim'),
#  ('Orot', 'Kefar Ahim'),
#  ('Oranim', 'Bet Zeid'),
#  ('Oranim', "Sha'ar HaAmaqim"),
#  ('Usha', 'Kefar HaMakkabbi'),
#  ('Ahawa', 'Kefar Ahim'),
#  ('Ahawa', 'Kefar Harif'),
#  ('Ahuzzam', 'Etan'),
#  ('Ahuzzam', "No'am"),
#  ('Ahuzzam', 'Shalwa'),
#  ('Ahihud', "Yas'ur"),
#  ('Ilaniyya', 'Sede Ilan'),
#  ('Irus', 'Bet Hanan'),
#  ('Irus', 'Bet Oved'),
#  ('Irus', 'Gan Soreq'),
#  ('Irus', "Neta'im"),
#  ('Irus', 'Ayanot'),
#  ('Etan', 'Uza'),
#  ('Etan', 'Shalwa'),
#  ('Etanim', 'Zova'),
#  ('Etanim', "Ramat Razi'el"),
#  ('Etanim', "Sho'eva"),
#  ('Al-Azy', 'Kefar Harif'),
#  ('Al-Aryan', 'Me Ammi'),
#  ('Alummot', 'Deganya Alef'),
#  ('Alummot', 'Deganya Bet'),
#  ('Alummot', 'Kinneret(Moshava)'),
#  ('Alummot', 'Kinneret(Qevuza)'),
#  ('Alummot', 'Poriyya-Kefar Avoda'),
#  ('Allone Yizhaq', 'Kefar Glikson'),
#  ('Eli-Ad', 'Geshur'),
#  ('Eliav', 'Amazya'),
#  ('Eliav', 'Karme Katif'),
#  ('Eliav', 'Sheqef'),
#  ('Elifelet', "Ammi'ad"),
#  ('Elyaqim', 'En HaEmeq'),
#  ('Elyashiv', "Ge'ule Teman"),
#  ('Elyashiv', 'HaOgen'),
#  ('Elyashiv', 'Hogla'),
#  ('Elyashiv', 'Hibbat Ziyyon'),
#  ('Elyashiv', "Herev Le'Et"),
#  ('Elyashiv', "Ma'barot"),
#  ('Elyashiv', 'Mishmar HaSharon'),
#  ('Elyashiv', 'En HaHoresh'),
#  ('Almagor', 'Karkom'),
#  ('Almog', 'Bet HaArava'),
#  ('Amirim', 'Kefar Shammay'),
#  ('Amirim', 'Parod'),
#  ('Amirim', 'Shefer'),
#  ('Amnun', 'Korazim'),
#  ('Amazya', 'Karme Katif'),
#  ('Amazya', 'Sheqef'),
#  ('Afiq', "Giv'at Yo'av"),
#  ('Afiq', "Ne'ot Golan"),
#  ('Arbel', 'Kefar Zetim'),
#  ('Arbel', 'Kefar Hittim'),
#  ('Erez', 'Netiv Haasara'),
#  ('Arsuf', "Ga'ash"),
#  ('Eshbol', "Pa'ame Tashaz"),
#  ('Eshbol', 'Qelahim'),
#  ('Eshbol', 'Talme Bilu'),
#  ('Eshbal', 'Eshhar'),
#  ('Eshbal', 'Hussniyya'),
#  ('Eshbal', 'Arab Al Naim'),
#  ('Eshbal', 'Zviyya'),
#  ("Ashdot Ya'aqov(Me'uhad)", 'Massada'),
#  ('Eshhar', 'Hussniyya'),
#  ('Eshhar', 'Arab Al Naim'),
#  ('Eshhar', 'Zviyya'),
#  ('Asherat', 'Bet HaEmeq'),
#  ('Asherat', 'Amqa'),
#  ("Be'erot Yizhaq", 'Bene Atarot'),
#  ("Be'erot Yizhaq", "Giv'at Koah"),
#  ("Be'erot Yizhaq", 'Nofekh'),
#  ('Bitha', 'Peduyim'),
#  ('Bitha', 'Rannen'),
#  ('Bet Berl', 'Gan Hayyim'),
#  ('Bet Berl', 'Nir Eliyyahu'),
#  ('Bet Guvrin', 'Kefar Zoharim'),
#  ('Bet HaGaddi', 'Yoshivya'),
#  ('Bet HaGaddi', 'Sharsheret'),
#  ('Bet HaLewi', 'Hadar Am'),
#  ('Bet HaLewi', 'HaOgen'),
#  ('Bet HaLewi', "Hanni'el"),
#  ('Bet HaLewi', 'Kefar Hayyim'),
#  ('Bet HaLewi', 'Kefar Monash'),
#  ('Bet HaLewi', 'Midreshet Ruppin'),
#  ('Bet HaLewi', "Ma'barot"),
#  ('Bet HaLewi', 'Mishmar HaSharon'),
#  ('Bet HaEmeq', 'Nes Ammim'),
#  ('Bet HaEmeq', 'Netiv HaShayyara'),
#  ('Bet HaEmeq', 'Amqa'),
#  ('Bet Zeid', "Sha'ar HaAmaqim"),
#  ('Bet Zera', 'Deganya Alef'),
#  ('Bet Zera', 'Deganya Bet'),
#  ('Bet Zera', 'Kinneret(Qevuza)'),
#  ('Bet Zera', 'Massada'),
#  ('Bet Zera', "Sha'ar HaGolan"),
#  ('Bet Herut', 'Bet Yannay'),
#  ('Bet Herut', 'Bitan Aharon'),
#  ('Bet Herut', 'Bat Hen'),
#  ('Bet Herut', "Giv'at Shappira"),
#  ('Bet Herut', 'Havazzelet HaSharon'),
#  ('Bet Herut', 'Hofit'),
#  ('Bet Herut', "Mevo'ot Yam"),
#  ('Bet Herut', "Ne'urim"),
#  ('Bet Herut', 'Zuqi Yam'),
#  ('Bet Herut', 'Shoshannat HaAmaqim'),
#  ('Bet Hanan', 'Bet Oved'),
#  ('Bet Hanan', 'Gan Soreq'),
#  ('Bet Hanan', "Neta'im"),
#  ('Bet Hanan', 'Ayanot'),
#  ('Bet Yosef', 'Yardena'),
#  ('Bet Yannay', 'Bitan Aharon'),
#  ('Bet Yannay', 'Bat Hen'),
#  ('Bet Yannay', "Giv'at Shappira"),
#  ('Bet Yannay', 'Havazzelet HaSharon'),
#  ('Bet Yannay', 'Hofit'),
#  ('Bet Yannay', "Mevo'ot Yam"),
#  ('Bet Yannay', "Ne'urim"),
#  ('Bet Yannay', 'Zuqi Yam'),
#  ("Bet Me'ir", 'Kesalon'),
#  ('Bet Nehemya', 'Hadid'),
#  ('Bet Nehemya', 'Kefar Truman'),
#  ('Bet Nehemya', 'Kerem Ben Shemen'),
#  ('Bet Nir', "Gal'on"),
#  ('Bet Neqofa', 'Yedida'),
#  ('Bet Neqofa', "Ma'ale HaHamisha"),
#  ('Bet Neqofa', 'Zova'),
#  ('Bet Neqofa', "Qiryat Ye'arim(Institute)"),
#  ('Bet Neqofa', 'Qiryat Anavim'),
#  ('Bet Oved', 'Gan Soreq'),
#  ('Bet Oved', "Neta'im"),
#  ('Bet Oved', 'Ayanot'),
#  ("Bet Uzzi'el", 'Gezer'),
#  ("Bet Uzzi'el", 'Pedaya'),
#  ("Bet Uzzi'el", 'Petahya'),
#  ('Bet Zevi', 'Nir Ezyon'),
#  ('Bet Zevi', 'En Hod'),
#  ('Bet Qeshet', 'Kadoorie'),
#  ('Bet Rabban', 'Kannot'),
#  ('Bet Rabban', 'Kefar Aviv'),
#  ('Bet Rabban', 'Kefar Mordekhay'),
#  ('Bet Rabban', 'Kerem Yavne(Yeshiva)'),
#  ('Bet Rabban', 'Meshar'),
#  ('Bet Rabban', 'Misgav Dov'),
#  ('Bet Rabban', 'Newe Mivtah'),
#  ('Bet Rabban', 'Aseret'),
#  ('Bet Rabban', 'Qevuzat Yavne'),
#  ('Bet Rabban', 'Shedema'),
#  ('Bet Shiqma', 'Bat Hadar'),
#  ('Bet Shiqma', "Ge'a"),
#  ('Bet Shiqma', 'Talme Yafe'),
#  ('Bitan Aharon', 'Bat Hen'),
#  ('Bitan Aharon', "Giv'at Shappira"),
#  ('Bitan Aharon', 'Havazzelet HaSharon'),
#  ('Bitan Aharon', 'Hofit'),
#  ('Bitan Aharon', "Ne'urim"),
#  ('Bitan Aharon', 'Zuqi Yam'),
#  ('Bitan Aharon', 'Shoshannat HaAmaqim'),
#  ('Balfurya', "Kefar Gid'on"),
#  ('Balfurya', 'Mizra'),
#  ('Ben Ammi', 'Netiv HaShayyara'),
#  ('Ben Ammi', 'Evron'),
#  ("Ben Shemen(K.No'ar)", 'Ben Shemen (Moshav)'),
#  ("Ben Shemen(K.No'ar)", 'Ginnaton'),
#  ("Ben Shemen(K.No'ar)", 'Hadid'),
#  ("Ben Shemen(K.No'ar)", 'Kefar Daniyyel'),
#  ("Ben Shemen(K.No'ar)", 'Kefar Truman'),
#  ("Ben Shemen(K.No'ar)", 'Kerem Ben Shemen'),
#  ('Ben Shemen (Moshav)', 'Ginnaton'),
#  ('Ben Shemen (Moshav)', 'Hadid'),
#  ('Ben Shemen (Moshav)', 'Kefar Daniyyel'),
#  ('Ben Shemen (Moshav)', 'Kerem Ben Shemen'),
#  ('Bene Darom', 'Gan HaDarom'),
#  ('Bene Darom', 'Kerem Yavne(Yeshiva)'),
#  ('Bene Darom', 'Qevuzat Yavne'),
#  ('Bene Atarot', "Giv'at Koah"),
#  ('Bene Atarot', 'Nofekh'),
#  ('Benaya', 'Kefar Mordekhay'),
#  ('Benaya', 'Meshar'),
#  ('Benaya', 'Misgav Dov'),
#  ('Benaya', 'Aseret'),
#  ('Benaya', 'Shedema'),
#  ('Bezet', 'Liman'),
#  ('Beqoa', 'Gizo'),
#  ('Beqoa', 'Nahshon'),
#  ('Bar Giyyora', 'Matta'),
#  ('Berosh', "Te'ashur"),
#  ('Berosh', 'Tidhar'),
#  ("Bar'am", 'Dovev'),
#  ("Bar'am", "Yir'on"),
#  ('Baraq', 'Gadish'),
#  ('Baraq', 'Devora'),
#  ('Baraq', 'Hever'),
#  ('Baraq', 'Ram-On'),
#  ('Barqay', "Ma'anit"),
#  ('Barqay', 'En Iron'),
#  ('Barqay', 'En Shemer'),
#  ('Bat Hadar', "Ge'a"),
#  ('Bat Hen', "Giv'at Shappira"),
#  ('Bat Hen', 'Hadar Am'),
#  ('Bat Hen', 'Havazzelet HaSharon'),
#  ('Bat Hen', 'Hofit'),
#  ('Bat Hen', 'Kefar Hayyim'),
#  ('Bat Hen', 'Kefar Yedidya'),
#  ('Bat Hen', 'Mishmar HaSharon'),
#  ('Bat Hen', "Ne'urim"),
#  ('Bat Hen', 'Zuqi Yam'),
#  ('Bat Hen', 'Shoshannat HaAmaqim'),
#  ("Ge'ule Teman", 'Hogla'),
#  ("Ge'ule Teman", 'Hofit'),
#  ("Ge'ule Teman", 'Hibbat Ziyyon'),
#  ("Ge'ule Teman", "Herev Le'Et"),
#  ("Ge'ulim", 'Yanuv'),
#  ("Ge'ulim", 'Tenuvot'),
#  ('Gevim', 'Yakhini'),
#  ('Gevim', 'Nir Am'),
#  ('Geva', "Gid'ona"),
#  ('Geva', 'En Harod (Ihud)'),
#  ('Geva', "En Harod(Me'uhad)"),
#  ('Geva', 'Tel Yosef'),
#  ("Giv'olim", 'Melilot'),
#  ("Giv'olim", 'Shibbolim'),
#  ("Giv'olim", 'Sharsheret'),
#  ("Giv'at HaShelosha", 'Enat'),
#  ("Giv'at Hen", 'Kefar Malal'),
#  ("Giv'at Yo'av", "Ne'ot Golan"),
#  ("Giv'at Yesha'yahu", 'Zafririm'),
#  ("Giv'at Koah", 'Nofekh'),
#  ("Giv'at Nili", 'Ammiqam'),
#  ("Giv'at Nili", 'Regavim'),
#  ("Giv'at Shemesh", 'Deir Rafat'),
#  ("Giv'at Shemesh", "Yish'i"),
#  ("Giv'at Shemesh", 'Kefar Uriyya'),
#  ("Giv'at Shemesh", "Zor'a"),
#  ("Giv'at Shemesh", 'Tarum'),
#  ("Giv'at Shappira", 'Hadar Am'),
#  ("Giv'at Shappira", 'Havazzelet HaSharon'),
#  ("Giv'at Shappira", 'Kefar Hayyim'),
#  ("Giv'at Shappira", 'Kefar Yedidya'),
#  ("Giv'at Shappira", "Ma'barot"),
#  ("Giv'at Shappira", 'Mishmar HaSharon'),
#  ("Giv'at Shappira", "Ne'urim"),
#  ("Giv'at Shappira", 'Zuqi Yam'),
#  ("Giv'at Shappira", 'Shoshannat HaAmaqim'),
#  ("Gevar'am", 'Talme Yafe'),
#  ('Gevat', 'Ramat Dawid'),
#  ('Gevat', 'Sarid'),
#  ('Gadot', 'Mishmar HaYarden'),
#  ('Gadish', 'Devora'),
#  ('Gadish', 'Hever'),
#  ('Gadish', "Mele'a"),
#  ('Gadish', 'Nir Yafe'),
#  ("Gid'ona", 'Nurit'),
#  ('Gonen', 'Lahavot HaBashan'),
#  ('Goren', 'Gornot HaGalil'),
#  ('Goren', 'Hilla'),
#  ('Gornot HaGalil', 'Hilla'),
#  ('Gezer', "Kefar Shemu'el"),
#  ('Gezer', 'Mishmar Ayyalon'),
#  ("Ge'a", "Mavqi'im"),
#  ("Ge'a", 'Talme Yafe'),
#  ('Gibbeton', 'Gan Shelomo'),
#  ('Gizo', "Har'el"),
#  ('Gizo', 'Kefar Uriyya'),
#  ('Ginnegar', 'Sarid'),
#  ('Ginnaton', 'Hadid'),
#  ('Ginnaton', 'Kefar Truman'),
#  ('Ginnaton', 'Kerem Ben Shemen'),
#  ('Gitta', 'Kishor'),
#  ('Gitta', 'Lappidot'),
#  ('Gilgal', 'Netiv HaGedud'),
#  ('Gilgal', 'Tomer'),
#  ('Gan HaDarom', 'Kerem Yavne(Yeshiva)'),
#  ('Gan HaDarom', 'Qevuzat Yavne'),
#  ('Gan Hashomeron', "Ma'anit"),
#  ('Gan Hashomeron', 'En Iron'),
#  ('Gan Hashomeron', 'En Shemer'),
#  ('Gan Hashomeron', "Sha'ar Menashe"),
#  ('Gan Hashomeron', "Talme El'azar"),
#  ('Gan Soreq', "Neta'im"),
#  ("Gan Shemu'el", "Talme El'azar"),
#  ('Gannot Hadar', 'Kefar Yedidya'),
#  ('Gannot Hadar', 'Midreshet Ruppin'),
#  ('Ganne Hadar', 'Ganne Yohanan'),
#  ('Ganne Hadar', 'Yaziz'),
#  ('Ganne Hadar', "Ramot Me'ir"),
#  ('Ganne Tal', 'Hafez Hayyim'),
#  ('Ganne Tal', 'Revadim'),
#  ('Ganne Yohanan', 'Yaziz'),
#  ('Ganne Yohanan', "Ramot Me'ir"),
#  ('Ganne Am', 'Yarqona'),
#  ('Ganne Am', 'Kefar Malal'),
#  ('Ganne Am', 'Adanim'),
#  ("Ga'ash", 'Yaqum'),
#  ("Ga'ton", "Yehi'am"),
#  ('Gefen', 'Tirosh'),
#  ('Gat(Qibbuz)', 'Sede Moshe'),
#  ('Gat Rimmon', "Ma'as"),
#  ('Devora', 'Hever'),
#  ('Devora', "Mele'a"),
#  ('Devora', 'Nir Yafe'),
#  ('Devora', 'Ram-On'),
#  ('Deganya Alef', 'Deganya Bet'),
#  ('Deganya Alef', 'Kinneret(Moshava)'),
#  ('Deganya Alef', 'Kinneret(Qevuza)'),
#  ('Deganya Alef', "Ma'agan"),
#  ('Deganya Alef', 'Poriyya-Kefar Avoda'),
#  ('Deganya Bet', 'Kinneret(Moshava)'),
#  ('Deganya Bet', 'Kinneret(Qevuza)'),
#  ('Deganya Bet', 'Massada'),
#  ('Deganya Bet', "Ma'agan"),
#  ('Dovev', 'Sasa'),
#  ('Dor', 'Nahsholim'),
#  ('Deir Rafat', 'Kefar Uriyya'),
#  ('Deir Rafat', "Zor'a"),
#  ('Dishon', 'Malkiyya'),
#  ('Daliyya', 'En HaShofet'),
#  ('Dalton', 'Kaddita'),
#  ('Dan', "She'ar Yashuv"),
#  ('Dan', 'Senir'),
#  ('Deqel', 'Yevul'),
#  ('Deqel', 'Yated'),
#  ('Deqel', 'Sede Avraham'),
#  ('Deqel', 'Talme Yosef'),
#  ('HaOn', "Ma'agan"),
#  ('HaOn', 'Tel Qazir'),
#  ('HaBonim', 'Nahsholim'),
#  ('Hadar Am', 'HaOgen'),
#  ('Hadar Am', 'Kefar Hayyim'),
#  ('Hadar Am', 'Kefar Yedidya'),
#  ('Hadar Am', 'Kefar Monash'),
#  ('Hadar Am', 'Midreshet Ruppin'),
#  ('Hadar Am', "Ma'barot"),
#  ('Hadar Am', 'Mishmar HaSharon'),
#  ('Hodayot', 'Lavi'),
#  ('Hodiyya', 'Kefar Silver'),
#  ('Hodiyya', "Nir Yisra'el"),
#  ('HaHoterim', 'Kefar Gallim'),
#  ('Hilla', "Me'ona"),
#  ('HaOgen', 'Hogla'),
#  ('HaOgen', 'Kefar Hayyim'),
#  ('HaOgen', 'Kefar Monash'),
#  ('HaOgen', 'Midreshet Ruppin'),
#  ('HaOgen', "Ma'barot"),
#  ('HaOgen', 'Mishmar HaSharon'),
#  ('Har Amasa', 'Mezadot Yehuda'),
#  ("Har'el", 'Kefar Uriyya'),
#  ("Har'el", 'Newe Shalom'),
#  ("Har'el", 'Nahshon'),
#  ("Har'el", "Ta'oz"),
#  ('Wardon', "Zavdi'el"),
#  ('Wardon', 'Menuha'),
#  ('Wardon', 'Nahala'),
#  ('Wardon', 'Nir Banim'),
#  ('Wardon', 'Segulla'),
#  ("Zavdi'el", 'Zerahya'),
#  ("Zavdi'el", 'Menuha'),
#  ("Zavdi'el", 'Nir Banim'),
#  ("Zavdi'el", 'Segulla'),
#  ("Zavdi'el", 'Qomemiyyut'),
#  ("Zavdi'el", 'Rewaha'),
#  ('Zohar', 'Nir Hen'),
#  ('Zohar', 'Sede Dawid'),
#  ('Ziqim', 'Karmiyya'),
#  ('Zimrat', 'Kefar Maymon'),
#  ('Zimrat', 'Shuva'),
#  ('Zimrat', 'Tushiyya'),
#  ('Zimrat', 'Tequma'),
#  ('Zanoah', 'Mahseya'),
#  ("Zeru'a", 'Yoshivya'),
#  ("Zeru'a", 'Nir Moshe'),
#  ("Zeru'a", 'Nir Aqiva'),
#  ("Zeru'a", 'Shave Darom'),
#  ('Zerahya', 'Nir Banim'),
#  ('Zerahya', 'En Zurim'),
#  ('Zerahya', 'Qomemiyyut'),
#  ('Zerahya', 'Shafir'),
#  ('Khawaled', 'Kefar HaMakkabbi'),
#  ('Khawaled', "Sawa'id(Hamriyye)"),
#  ('Khawaled', 'Ras Ali'),
#  ('Havazzelet HaSharon', 'Hofit'),
#  ('Havazzelet HaSharon', "Ne'urim"),
#  ('Havazzelet HaSharon', 'Zuqi Yam'),
#  ('Havazzelet HaSharon', 'Shoshannat HaAmaqim'),
#  ('Hever', 'Nir Yafe'),
#  ('Hever', 'Ram-On'),
#  ('Hogla', 'Hibbat Ziyyon'),
#  ('Hogla', "Herev Le'Et"),
#  ('Hogla', 'En HaHoresh'),
#  ('Hadid', 'Kefar Truman'),
#  ('Hadid', 'Kerem Ben Shemen'),
#  ('Holit', 'Yated'),
#  ('Holit', 'Sufa'),
#  ('Holit', 'Peri Gan'),
#  ('Holit', 'Sede Avraham'),
#  ('Hussniyya', 'Mikhmannim'),
#  ('Hussniyya', 'Zviyya'),
#  ('Hofit', "Mevo'ot Yam"),
#  ('Hofit', "Ne'urim"),
#  ('Hofit', 'Zuqi Yam'),
#  ('Huqoq', 'Kahal'),
#  ('Huqoq', 'Livnim'),
#  ('Huqoq', 'Qaddarim'),
#  ('Horeshim', 'Nirit'),
#  ('Hazon', 'Kefar Hananya'),
#  ('Hazon', 'Moran'),
#  ('Hazon', 'Ras Al-Ein'),
#  ('Hibbat Ziyyon', "Herev Le'Et"),
#  ('Hibbat Ziyyon', 'En HaHoresh'),
#  ('Haluz', 'Harashim'),
#  ('Haluz', 'Lavon'),
#  ('Helez', 'Sede Dawid'),
#  ('Helez', 'Telamim'),
#  ("Hanni'el", 'Yanuv'),
#  ('Hanita', "Ya'ara"),
#  ('Hafez Hayyim', 'Revadim'),
#  ("Herev Le'Et", 'En HaHoresh'),
#  ('Haruzim', 'Qiryat Shelomo'),
#  ('Haruzim', 'Tel Yizhaq'),
#  ('Tirat Zevi', 'Sede Eliyyahu'),
#  ('Telalim', "Mash'abbe Sade"),
#  ('Telalim', 'Shezaf'),
#  ('Tefahot', 'Massad'),
#  ('Yevul', 'Yated'),
#  ('Yevul', 'Shlomit'),
#  ('Yad HaShemona', 'Yedida'),
#  ('Yad HaShemona', "Ma'ale HaHamisha"),
#  ('Yad HaShemona', 'Newe Ilan'),
#  ('Yad HaShemona', "Qiryat Ye'arim(Institute)"),
#  ('Yad HaShemona', 'Qiryat Anavim'),
#  ('Yad HaShemona', "Sho'eva"),
#  ('Yad Mordekhay', 'Karmiyya'),
#  ('Yad Mordekhay', 'Netiv Haasara'),
#  ('Yad Natan', 'Negba'),
#  ('Yad Natan', 'Ozem'),
#  ('Yad Natan', 'Qomemiyyut'),
#  ('Yad Natan', 'Rewaha'),
#  ('Yad Natan', "Sede Yo'av"),
#  ('Yedida', "Ma'ale HaHamisha"),
#  ('Yedida', 'Newe Ilan'),
#  ('Yedida', "Qiryat Ye'arim(Institute)"),
#  ('Yedida', 'Qiryat Anavim'),
#  ('Yuval', "Kefar Gil'adi"),
#  ('Yuval', "Ma'yan Barukh"),
#  ('Yodefat', 'Qoranit'),
#  ('Yodefat', 'Shekhanya'),
#  ('Yoshivya', 'Tequma'),
#  ("Yizre'el", 'Metav'),
#  ("Yizre'el", 'Perazon'),
#  ("Yehi'am", 'Kelil'),
#  ('Yanuv', 'Tenuvot'),
#  ("Ya'ad", 'Manof'),
#  ("Ya'ad", 'Zurit'),
#  ("Ya'ad", 'Shorashim'),
#  ("Ye'af", "Kefar Ya'bez"),
#  ("Ye'af", 'Kefar Avoda'),
#  ("Ye'af", "Azri'el"),
#  ("Ya'ara", 'Avdon'),
#  ('Yaziz', 'Pedaya'),
#  ('Yaziz', 'Petahya'),
#  ('Yaziz', "Ramot Me'ir"),
#  ('Yaqum', 'Qiryat Shelomo'),
#  ('Yaqum', 'Tel Yizhaq'),
#  ('Yardena', 'Newe Ur'),
#  ('Yarqona', 'Kefar Malal'),
#  ('Yarqona', 'Adanim'),
#  ('Yesha', 'Mivtahim'),
#  ('Yesha', "Ammi'oz"),
#  ('Yesha', 'Zohar'),
#  ('Yesha', 'Sede Nizzan'),
#  ("Yish'i", "Zor'a"),
#  ('Yashresh', 'Nezer Sereni'),
#  ('Yated', 'Sede Avraham'),
#  ('Kadoorie', 'Shadmot Devora'),
#  ('Kaddita', 'Kefar Hoshen'),
#  ('Korazim', "Ammi'ad"),
#  ('Kissufim', 'En HaShelosha'),
#  ('Kishor', 'Lappidot'),
#  ('Kishor', 'Pelekh'),
#  ('Kishor', 'Tuval'),
#  ('Kallanit', 'Ravid'),
#  ('Kemehin', 'Nizzana (Qehilat Hinuh)'),
#  ('Kannot', 'Meshar'),
#  ('Kannot', 'Misgav Dov'),
#  ('Kannot', 'Newe Mivtah'),
#  ('Kannot', 'Aseret'),
#  ('Kanaf', "Ma'ale Gamla"),
#  ('Kinneret(Moshava)', 'Kinneret(Qevuza)'),
#  ('Kinneret(Moshava)', 'Poriyya-Kefar Avoda'),
#  ('Kinneret(Qevuza)', 'Poriyya-Kefar Avoda'),
#  ('Kesalon', "Ramat Razi'el"),
#  ('Kefar Aviv', 'Kerem Yavne(Yeshiva)'),
#  ('Kefar Aviv', 'Misgav Dov'),
#  ('Kefar Aviv', 'Aseret'),
#  ('Kefar Aviv', 'Qevuzat Yavne'),
#  ('Kefar Aviv', 'Shedema'),
#  ('Kefar Uriyya', "Ta'oz"),
#  ('Kefar Blum', "Ne'ot Mordekhay"),
#  ('Kefar Blum', 'Amir'),
#  ('Kefar Bin Nun', 'Mishmar Ayyalon'),
#  ("Kefar Gid'on", 'Mizra'),
#  ('Kefar Glikson', 'En Iron'),
#  ("Kefar Gil'adi", 'Misgav Am'),
#  ('Kefar Daniyyel', 'Kerem Ben Shemen'),
#  ("Kefar HaNo'ar Hadati", 'Kefar Hasidim Alef'),
#  ("Kefar HaNo'ar Hadati", 'Kefar Hasidim Bet'),
#  ("Kefar HaNo'ar Hadati", "Sha'ar HaAmaqim"),
#  ('Kefar Hoshen', "Ziv'on"),
#  ('Kefar Hittim', 'Mizpa'),
#  ('Kefar Hayyim', 'Kefar Yedidya'),
#  ('Kefar Hayyim', 'Kefar Monash'),
#  ('Kefar Hayyim', 'Midreshet Ruppin'),
#  ('Kefar Hayyim', "Ma'barot"),
#  ('Kefar Hayyim', 'Mishmar HaSharon'),
#  ('Kefar Hananya', 'Moran'),
#  ('Kefar Hananya', 'Parod'),
#  ('Kefar Hasidim Alef', 'Kefar Hasidim Bet'),
#  ('Kefar Haruv', 'Mevo Hamma'),
#  ('Kefar Truman', 'Kerem Ben Shemen'),
#  ('Kefar Yedidya', 'Kefar Monash'),
#  ('Kefar Yedidya', 'Midreshet Ruppin'),
#  ('Kefar Yedidya', "Ma'barot"),
#  ('Kefar Yedidya', 'Mishmar HaSharon'),
#  ("Kefar Ya'bez", "Azri'el"),
#  ('Kefar Monash', 'Midreshet Ruppin'),
#  ('Kefar Monash', "Ma'barot"),
#  ('Kefar Monash', 'Mishmar HaSharon'),
#  ('Kefar Maymon', 'Shuva'),
#  ('Kefar Maymon', 'Shoqeda'),
#  ('Kefar Maymon', 'Tushiyya'),
#  ('Kefar Mordekhay', 'Meshar'),
#  ('Kefar Mordekhay', 'Misgav Dov'),
#  ('Kefar Mordekhay', 'Aseret'),
#  ('Kefar Mordekhay', 'Shedema'),
#  ('Kefar Silver', "Nir Yisra'el"),
#  ('Kefar Avoda', "Azri'el"),
#  ('Kefar Azza', "Sa'ad"),
#  ('Kefar Rozenwald(Zarit)', 'Shomera'),
#  ('Kefar Rozenwald(Zarit)', 'Shetula'),
#  ('Kefar Rut', 'Mattityahu'),
#  ('Kefar Rut', 'Shilat'),
#  ('Kefar Shammay', 'Shefer'),
#  ("Kefar Shemu'el", 'Mishmar Ayyalon'),
#  ('Kerem Yavne(Yeshiva)', 'Meshar'),
#  ('Kerem Yavne(Yeshiva)', 'Misgav Dov'),
#  ('Kerem Yavne(Yeshiva)', 'Newe Mivtah'),
#  ('Kerem Yavne(Yeshiva)', 'Aseret'),
#  ('Kerem Yavne(Yeshiva)', 'Qevuzat Yavne'),
#  ('Kerem Yavne(Yeshiva)', 'Shedema'),
#  ('Kerem Maharal', 'Ofer'),
#  ('Karmel', "Ma'on"),
#  ('Lavon', 'Lappidot'),
#  ('Luzit', 'Agur'),
#  ("Lohame HaGeta'ot", 'Nes Ammim'),
#  ("Lohame HaGeta'ot", 'Shamerat'),
#  ('Lotem', 'Zviyya'),
#  ('Mivtahim', "Ammi'oz"),
#  ('Mivtahim', 'Zohar'),
#  ('Mivtahim', 'Sede Nizzan'),
#  ('Mivtahim', 'Talme Eliyyahu'),
#  ('Megiddo', 'Midrakh Oz'),
#  ('Magen', 'Nir Oz'),
#  ("Magen Sha'ul", 'Metav'),
#  ("Magen Sha'ul", 'Perazon'),
#  ('Midreshet Ruppin', "Ma'barot"),
#  ('Midreshet Ruppin', 'Mishmar HaSharon'),
#  ('Moran', 'Ein Al-Asad'),
#  ('Moran', 'Ras Al-Ein'),
#  ('Mehola', 'Shadmot Mehola'),
#  ('Mahane Yattir', 'Shani'),
#  ('Mahseya', 'Naham'),
#  ('Metav', 'Perazon'),
#  ('Merav', 'Malkishua'),
#  ('Merav', "Ma'ale Gilboa"),
#  ('Meshar', 'Misgav Dov'),
#  ('Meshar', 'Newe Mivtah'),
#  ('Meshar', 'Aseret'),
#  ('Meshar', 'Shedema'),
#  ('Mikhmannim', 'Zviyya'),
#  ("Mele'a", 'Nir Yafe'),
#  ('Melilot', 'Shibbolim'),
#  ('Melilot', 'Sharsheret'),
#  ('Menuha', 'Nahala'),
#  ('Menuha', 'Nir Banim'),
#  ('Menuha', 'Segulla'),
#  ('Manof', 'Qoranit'),
#  ('Manof', 'Shekhanya'),
#  ('Manot', 'Avdon'),
#  ('Menara', 'Margaliyyot'),
#  ('Massada', "Ma'agan"),
#  ('Massada', "Sha'ar HaGolan"),
#  ('Massada', 'Tel Qazir'),
#  ('Mesillot', 'Nir Dawid (Tel Amal)'),
#  ('Mesillot', 'Sheluhot'),
#  ('Maslul', 'Peduyim'),
#  ('Maslul', 'Pattish'),
#  ('Maslul', 'Rannen'),
#  ("Ma'barot", 'Mishmar HaSharon'),
#  ("Ma'agan", "Sha'ar HaGolan"),
#  ("Ma'agan", 'Tel Qazir'),
#  ("Ma'oz Hayyim", 'Newe Etan'),
#  ("Ma'ale HaHamisha", 'Newe Ilan'),
#  ("Ma'ale HaHamisha", "Qiryat Ye'arim(Institute)"),
#  ("Ma'ale HaHamisha", 'Qiryat Anavim'),
#  ("Ma'anit", 'Mezer'),
#  ("Ma'anit", 'En Shemer'),
#  ("Ma'anit", "Sha'ar Menashe"),
#  ("Mash'abbe Sade", 'Shezaf'),
#  ('Misgav Dov', 'Newe Mivtah'),
#  ('Misgav Dov', 'Aseret'),
#  ('Misgav Dov', 'Qevuzat Yavne'),
#  ('Misgav Dov', 'Shedema'),
#  ("Massu'ot Yizhaq", 'En Zurim'),
#  ('Maskiyyot', 'Rotem'),
#  ('Mattityahu', 'Shilat'),
#  ("Ne'ot HaKikkar", 'En Tamar'),
#  ("Ne'ot Mordekhay", 'Amir'),
#  ("Ne'ot Smadar", 'Newe Harif'),
#  ('Negba', "Sede Yo'av"),
#  ('Nogah', 'Nir Hen'),
#  ('Nogah', 'Ozem'),
#  ('Nogah', "Sede Yo'av"),
#  ('Nogah', 'Shahar'),
#  ('Newe Ilan', 'Nataf'),
#  ('Newe Ilan', "Qiryat Ye'arim(Institute)"),
#  ('Newe Ilan', "Sho'eva"),
#  ('Newe Yam', 'En Karmel'),
#  ('Newe Mivtah', 'Aseret'),
#  ('Newe Mivtah', 'Qevuzat Yavne'),
#  ('Newe Mivtah', 'Shedema'),
#  ("Newe Mikha'el", 'Netiv HaLamed-He'),
#  ('Newe Shalom', 'Nahshon'),
#  ('Newe Shalom', "Ta'oz"),
#  ("No'am", 'Shalwa'),
#  ('Nahal Oz', 'Alumim'),
#  ('Nahala', 'Segulla'),
#  ('Naham', 'Tarum'),
#  ('Nahshonim', 'Enat'),
#  ("Netu'a", 'Shetula'),
#  ('Nizzan B', 'Nizzanim'),
#  ('Nir Banim', 'Segulla'),
#  ('Nir Banim', 'Qomemiyyut'),
#  ('Nir Hen', 'Shahar'),
#  ('Nir Yizhaq', 'Sufa'),
#  ('Nir Yizhaq', 'Peri Gan'),
#  ('Nir Moshe', 'Nir Aqiva'),
#  ('Nir Moshe', 'Shave Darom'),
#  ('Nir Oz', 'Nirim'),
#  ('Nir Ezyon', 'En Hod'),
#  ('Nir Ezyon', 'Ein Hod'),
#  ('Nir Aqiva', 'Shave Darom'),
#  ('Nirim', 'En HaShelosha'),
#  ('Nes Ammim', 'Shamerat'),
#  ("Ne'urim", 'Zuqi Yam'),
#  ("Ne'urim", 'Shoshannat HaAmaqim'),
#  ("Na'aran", 'Netiv HaGedud'),
#  ('Netiv HaShayyara', 'Amqa'),
#  ('Sasa', "Ziv'on"),
#  ("Sawa'id(Hamriyye)", 'Ras Ali'),
#  ('Sufa', 'Peri Gan'),
#  ('Sufa', 'Sede Avraham'),
#  ("Sa'ad", 'Alumim'),
#  ("Sa'ad", 'Shuva'),
#  ('Agur', 'Sedot Mikha'),
#  ('Ozem', "Sede Yo'av"),
#  ('Ozem', 'Shahar'),
#  ('En Hod', 'Ein Hod'),
#  ('En HaNaziv', 'Rehov'),
#  ('En HaNaziv', 'Sheluhot'),
#  ('En Harod (Ihud)', "En Harod(Me'uhad)"),
#  ('En Harod (Ihud)', 'Tel Yosef'),
#  ("En Harod(Me'uhad)", 'Tel Yosef'),
#  ('En Iron', 'En Shemer'),
#  ('En Zurim', 'Shafir'),
#  ('En Shemer', "Sha'ar Menashe"),
#  ('Alumim', 'Shuva'),
#  ("Ammi'oz", 'Zohar'),
#  ("Ammi'oz", 'Sede Nizzan'),
#  ("Ammi'oz", 'Talme Eliyyahu'),
#  ('Arab Al Naim', 'Shorashim'),
#  ('Aseret', 'Qevuzat Yavne'),
#  ('Aseret', 'Shedema'),
#  ('Peduyim', 'Rannen'),
#  ('Pedaya', 'Petahya'),
#  ('Pelekh', 'Tuval'),
#  ("Pa'ame Tashaz", 'Qelahim'),
#  ("Pa'ame Tashaz", 'Sede Zevi'),
#  ("Peza'el", 'Tomer'),
#  ("Peqi'in Hadasha", "Zuri'el"),
#  ('Parod', 'Shefer'),
#  ('Peri Gan', 'Sede Avraham'),
#  ('Peri Gan', 'Talme Yosef'),
#  ('Petahya', "Ramot Me'ir"),
#  ('Zohar', 'Sede Nizzan'),
#  ('Zohar', 'Talme Eliyyahu'),
#  ('Zuqi Yam', 'Shoshannat HaAmaqim'),
#  ('Zurit', 'Shorashim'),
#  ('Zurit', 'Tuval'),
#  ("Zor'a", 'Tarum'),
#  ('Qevuzat Yavne', 'Shedema'),
#  ('Qomemiyyut', 'Rewaha'),
#  ('Qoranit', 'Shekhanya'),
#  ("Qiryat Ye'arim(Institute)", 'Qiryat Anavim'),
#  ("Qiryat Ye'arim(Institute)", "Sho'eva"),
#  ('Qiryat Shelomo', 'Tel Yizhaq'),
#  ('Ras Al-Ein', 'Shezor'),
#  ('Rewaya', 'Rehov'),
#  ('Rewaya', 'Sede Terumot'),
#  ('Rewaya', 'Sheluhot'),
#  ('Rewaya', "Tel Te'omim"),
#  ('Rotem', 'Shadmot Mehola'),
#  ('Rehov', 'Sede Eliyyahu'),
#  ('Rehov', 'Sede Terumot'),
#  ('Rehov', 'Sheluhot'),
#  ('Rehov', "Tel Te'omim"),
#  ('Ramat Dawid', 'Sarid'),
#  ("Ramat Razi'el", "Sho'eva"),
#  ('Sede Eliyyahu', 'Sede Terumot'),
#  ('Sede Eliyyahu', "Tel Te'omim"),
#  ('Sede Dawid', 'Telamim'),
#  ('Sede Nizzan', 'Talme Eliyyahu'),
#  ('Sede Avraham', 'Talme Yosef'),
#  ('Sede Terumot', "Tel Te'omim"),
#  ('Shuva', 'Tushiyya'),
#  ('Shomera', 'Shetula'),
#  ('Shoqeda', 'Tushiyya'),
#  ('Shibbolim', 'Sharsheret'),
#  ('Shibbolim', 'Tidhar'),
#  ("Sha'ar HaGolan", 'Tel Qazir'),
#  ("Te'ashur", 'Tidhar'),
#  ("Ta'oz", 'Tarum')]

# %%
len(nearby_pairs)
# Out:
# 777
